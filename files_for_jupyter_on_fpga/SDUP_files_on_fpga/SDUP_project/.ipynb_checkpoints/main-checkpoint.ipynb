# %%
from lib import run_test, open_spectrograph_fpga

# %%
run_test()
# Out:
# Ładowanie bitstreamu na FPGA...
# Generowanie sygnału testowego...
#
# --- Testowanie okna: Prostokątne (Rectangular) (window_type = 0) ---
# Błąd MSE (FPGA vs NumPy): 1012.9623
#
# --- Testowanie okna: Hann (Hanning) (window_type = 1) ---
# Błąd MSE (FPGA vs NumPy): 811.5754
#
# --- Testowanie okna: Blackman (window_type = 2) ---
# Błąd MSE (FPGA vs NumPy): 775.7118
#
# --- Testowanie okna: Flat Top (window_type = 3) ---
# Błąd MSE (FPGA vs NumPy): 774.0484

# %%
open_spectrograph_fpga()
# Out:
# [FPGA] Inicjalizacja Overlay...
# ...
# [SYSTEM ODBIORCZY] Wątek tła aktywny (FPGA). Nasłuch na 0.0.0.0:5005
